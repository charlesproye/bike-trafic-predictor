# %% [markdown]
# # ADD CURFEW

# %%
from pathlib import Path
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
import datetime

# %%
data = pd.read_parquet('./data/train.parquet')
data
# Out:
#                  counter_id                counter_name    site_id  \
# 48321   100007049-102007049    28 boulevard Diderot E-O  100007049
# 48324   100007049-102007049    28 boulevard Diderot E-O  100007049
# 48327   100007049-102007049    28 boulevard Diderot E-O  100007049
# 48330   100007049-102007049    28 boulevard Diderot E-O  100007049
# 48333   100007049-102007049    28 boulevard Diderot E-O  100007049
# ...                     ...                         ...        ...
# 928450  300014702-353245971  254 rue de Vaugirard SO-NE  300014702
# 928453  300014702-353245971  254 rue de Vaugirard SO-NE  300014702
# 928456  300014702-353245971  254 rue de Vaugirard SO-NE  300014702
# 928459  300014702-353245971  254 rue de Vaugirard SO-NE  300014702
# 928462  300014702-353245971  254 rue de Vaugirard SO-NE  300014702
#
#                    site_name  bike_count                date  \
# 48321   28 boulevard Diderot         0.0 2020-09-01 02:00:00
# 48324   28 boulevard Diderot         1.0 2020-09-01 03:00:00
# 48327   28 boulevard Diderot         0.0 2020-09-01 04:00:00
# 48330   28 boulevard Diderot         4.0 2020-09-01 15:00:00
# 48333   28 boulevard Diderot         9.0 2020-09-01 18:00:00
# ...                      ...         ...                 ...
# 928450  254 rue de Vaugirard        51.0 2021-08-08 18:00:00
# 928453  254 rue de Vaugirard         1.0 2021-08-09 02:00:00
# 928456  254 rue de Vaugirard        61.0 2021-08-09 08:00:00
# 928459  254 rue de Vaugirard        44.0 2021-08-09 10:00:00
# 928462  254 rue de Vaugirard        83.0 2021-08-09 17:00:00
#
#        counter_installation_date counter_technical_id   latitude  longitude  \
# 48321                 2013-01-18          Y2H15027244  48.846028   2.375429
# 48324                 2013-01-18          Y2H15027244  48.846028   2.375429
# 48327                 2013-01-18          Y2H15027244  48.846028   2.375429
# 48330                 2013-01-18          Y2H15027244  48.846028   2.375429
# 48333                 2013-01-18          Y2H15027244  48.846028   2.375429
# ...                          ...                  ...        ...        ...
# 928450                2020-11-29          Y2H20114504  48.839770   2.301980
# 928453                2020-11-29          Y2H20114504  48.839770   2.301980
# 928456                2020-11-29          Y2H20114504  48.839770   2.301980
# 928459                2020-11-29          Y2H20114504  48.839770   2.301980
# 928462                2020-11-29          Y2H20114504  48.839770   2.301980
#
#         log_bike_count
# 48321         0.000000
# 48324         0.693147
# 48327         0.000000
# 48330         1.609438
# 48333         2.302585
# ...                ...
# 928450        3.951244
# 928453        0.693147
# 928456        4.127134
# 928459        3.806662
# 928462        4.430817
#
# [455163 rows x 11 columns]

# %%
def _encode_dates(X):
    X = X.copy()  # modify a copy of X
    # Encode the date information from the DateOfDeparture columns
    X.loc[:, 'year'] = X['date'].dt.year
    X.loc[:, 'month'] = X['date'].dt.month
    X.loc[:, 'day'] = X['date'].dt.day
    X.loc[:, 'weekday'] = X['date'].dt.weekday
    X.loc[:, 'hour'] = X['date'].dt.hour

    # Finally we can drop the original columns from the dataframe
    return X.drop(columns=["date"])

# %%
def curfew(X):
    date = pd.to_datetime(X['date'])
    X.loc[:, ['date_only']] = date
    new_date = [dt.date() for dt in X['date_only']]
    X.loc[:, ['date_only']] = new_date
    X.loc[:, ['hour_only']] = date
    new_hour = [dt.hour for dt in X['hour_only']]
    X.loc[:, ['hour_only']] = new_hour
    mask = (
        #First curfew
        (X['date_only'] >= pd.to_datetime('2020/12/15'))
        & (X['date_only'] < pd.to_datetime('2021/01/16'))
        & ((X['hour_only'] >= 20) | (X['hour_only'] <= 6))

        | 
        
        # Second curfew
        (X['date_only'] >= pd.to_datetime('2021/01/16'))
        & (X['date_only'] < pd.to_datetime('2021/03/20'))
        & ((X['hour_only'] >= 18) | (X['hour_only'] <= 6))

        |

        # Third curfew
        (X['date_only'] >= pd.to_datetime('2021/03/20'))
        & (X['date_only'] < pd.to_datetime('2021/05/19'))
        & ((X['hour_only'] >= 19) | (X['hour_only'] <= 6))

        |

        # Fourth curfew
        (X['date_only'] >= pd.to_datetime('2021/05/19'))
        & (X['date_only'] < pd.to_datetime('2021/06/9'))
        & ((X['hour_only'] >= 21) | (X['hour_only'] <= 6))

        |

        # Fifth curfew
        (X['date_only'] >= pd.to_datetime('2021/06/9'))
        & (X['date_only'] < pd.to_datetime('2021/06/20'))
        & ((X['hour_only'] >= 21) | (X['hour_only'] <= 6))
        )
    X['curfew'] =np.where(mask, 1, 0)

    return X.drop(columns=['hour_only', 'date_only'])

curfew(data)
# Out:
#                  counter_id                counter_name    site_id  \
# 48321   100007049-102007049    28 boulevard Diderot E-O  100007049
# 48324   100007049-102007049    28 boulevard Diderot E-O  100007049
# 48327   100007049-102007049    28 boulevard Diderot E-O  100007049
# 48330   100007049-102007049    28 boulevard Diderot E-O  100007049
# 48333   100007049-102007049    28 boulevard Diderot E-O  100007049
# ...                     ...                         ...        ...
# 928450  300014702-353245971  254 rue de Vaugirard SO-NE  300014702
# 928453  300014702-353245971  254 rue de Vaugirard SO-NE  300014702
# 928456  300014702-353245971  254 rue de Vaugirard SO-NE  300014702
# 928459  300014702-353245971  254 rue de Vaugirard SO-NE  300014702
# 928462  300014702-353245971  254 rue de Vaugirard SO-NE  300014702
#
#                    site_name  bike_count                date  \
# 48321   28 boulevard Diderot         0.0 2020-09-01 02:00:00
# 48324   28 boulevard Diderot         1.0 2020-09-01 03:00:00
# 48327   28 boulevard Diderot         0.0 2020-09-01 04:00:00
# 48330   28 boulevard Diderot         4.0 2020-09-01 15:00:00
# 48333   28 boulevard Diderot         9.0 2020-09-01 18:00:00
# ...                      ...         ...                 ...
# 928450  254 rue de Vaugirard        51.0 2021-08-08 18:00:00
# 928453  254 rue de Vaugirard         1.0 2021-08-09 02:00:00
# 928456  254 rue de Vaugirard        61.0 2021-08-09 08:00:00
# 928459  254 rue de Vaugirard        44.0 2021-08-09 10:00:00
# 928462  254 rue de Vaugirard        83.0 2021-08-09 17:00:00
#
#        counter_installation_date counter_technical_id   latitude  longitude  \
# 48321                 2013-01-18          Y2H15027244  48.846028   2.375429
# 48324                 2013-01-18          Y2H15027244  48.846028   2.375429
# 48327                 2013-01-18          Y2H15027244  48.846028   2.375429
# 48330                 2013-01-18          Y2H15027244  48.846028   2.375429
# 48333                 2013-01-18          Y2H15027244  48.846028   2.375429
# ...                          ...                  ...        ...        ...
# 928450                2020-11-29          Y2H20114504  48.839770   2.301980
# 928453                2020-11-29          Y2H20114504  48.839770   2.301980
# 928456                2020-11-29          Y2H20114504  48.839770   2.301980
# 928459                2020-11-29          Y2H20114504  48.839770   2.301980
# 928462                2020-11-29          Y2H20114504  48.839770   2.301980
#
#         log_bike_count  curfew
# 48321         0.000000       0
# 48324         0.693147       0
# 48327         0.000000       0
# 48330         1.609438       0
# 48333         2.302585       0
# ...                ...     ...
# 928450        3.951244       0
# 928453        0.693147       0
# 928456        4.127134       0
# 928459        3.806662       0
# 928462        4.430817       0
#
# [455163 rows x 12 columns]

# %%
data[data['date_only'] == pd.to_datetime('2021-03-15')]
# Out:
#                  counter_id                counter_name    site_id  \
# 52850   100007049-102007049    28 boulevard Diderot E-O  100007049
# 52853   100007049-102007049    28 boulevard Diderot E-O  100007049
# 52856   100007049-102007049    28 boulevard Diderot E-O  100007049
# 52859   100007049-102007049    28 boulevard Diderot E-O  100007049
# 52862   100007049-102007049    28 boulevard Diderot E-O  100007049
# ...                     ...                         ...        ...
# 924988  300014702-353245971  254 rue de Vaugirard SO-NE  300014702
# 924991  300014702-353245971  254 rue de Vaugirard SO-NE  300014702
# 924994  300014702-353245971  254 rue de Vaugirard SO-NE  300014702
# 924997  300014702-353245971  254 rue de Vaugirard SO-NE  300014702
# 925000  300014702-353245971  254 rue de Vaugirard SO-NE  300014702
#
#                    site_name  bike_count                date  \
# 52850   28 boulevard Diderot         1.0 2021-03-15 05:00:00
# 52853   28 boulevard Diderot         5.0 2021-03-15 07:00:00
# 52856   28 boulevard Diderot         1.0 2021-03-15 09:00:00
# 52859   28 boulevard Diderot         3.0 2021-03-15 14:00:00
# 52862   28 boulevard Diderot         5.0 2021-03-15 15:00:00
# ...                      ...         ...                 ...
# 924988  254 rue de Vaugirard         0.0 2021-03-15 03:00:00
# 924991  254 rue de Vaugirard       188.0 2021-03-15 07:00:00
# 924994  254 rue de Vaugirard        84.0 2021-03-15 10:00:00
# 924997  254 rue de Vaugirard       105.0 2021-03-15 17:00:00
# 925000  254 rue de Vaugirard        37.0 2021-03-15 20:00:00
#
#        counter_installation_date counter_technical_id   latitude  longitude  \
# 52850                 2013-01-18          Y2H15027244  48.846028   2.375429
# 52853                 2013-01-18          Y2H15027244  48.846028   2.375429
# 52856                 2013-01-18          Y2H15027244  48.846028   2.375429
# 52859                 2013-01-18          Y2H15027244  48.846028   2.375429
# 52862                 2013-01-18          Y2H15027244  48.846028   2.375429
# ...                          ...                  ...        ...        ...
# 924988                2020-11-29          Y2H20114504  48.839770   2.301980
# 924991                2020-11-29          Y2H20114504  48.839770   2.301980
# 924994                2020-11-29          Y2H20114504  48.839770   2.301980
# 924997                2020-11-29          Y2H20114504  48.839770   2.301980
# 925000                2020-11-29          Y2H20114504  48.839770   2.301980
#
#         log_bike_count   date_only  hour_only  curfew
# 52850         0.693147  2021-03-15          5       1
# 52853         1.791759  2021-03-15          7       0
# 52856         0.693147  2021-03-15          9       0
# 52859         1.386294  2021-03-15         14       0
# 52862         1.791759  2021-03-15         15       0
# ...                ...         ...        ...     ...
# 924988        0.000000  2021-03-15          3       1
# 924991        5.241747  2021-03-15          7       0
# 924994        4.442651  2021-03-15         10       0
# 924997        4.663439  2021-03-15         17       0
# 925000        3.637586  2021-03-15         20       1
#
# [1296 rows x 14 columns]
